# %% [markdown]
# # 05 — Experiments & Final Comparison
#
# **Project:** High-Density Object Segmentation with Soft-NMS
#
# ---
#
# ## Objectives
# 1. Run all methods on the same test set for fair comparison
# 2. Generate comprehensive results table (mAP, count MAE, FPS)
# 3. Create performance-vs-occlusion analysis
# 4. Produce publication-quality figures for the report
# 5. Test edge pipeline (ONNX) latency on CPU
# 6. Summarize findings and actionable conclusions

# %%
import sys
sys.path.append('..')

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from pathlib import Path

from src.evaluation.metrics import *  # noqa
from src.utils.visualization import setup_style, save_figure, METHOD_COLORS

setup_style()
print('Libraries loaded.')

# %% [markdown]
# ## 1. Load All Method Results

# %%
# TODO: Load cached predictions from all methods
# methods = ['Heuristic', 'Watershed', 'Graph Seg', 'DL + Hard NMS', 'DL + Soft-NMS', 'Edge Pipeline']

# %% [markdown]
# ## 2. Results Table

# %%
# TODO: Generate comparison table
# | Method           | mAP@0.5 | mAP@0.5:0.95 | Count MAE | FPS  |
# |------------------|---------|---------------|-----------|------|
# | Heuristic        |         |               |           |      |
# | Watershed        |         |               |           |      |
# | Graph Seg        |         |               |           |      |
# | DL + Hard NMS    |         |               |           |      |
# | DL + Soft-NMS    |         |               |           |      |
# | Edge Pipeline    |         |               |           |      |

# %% [markdown]
# ## 3. Performance vs. Occlusion Level

# %%
# TODO: Plot mAP as a function of occlusion level (0%, 25%, 50%, 75%)

# %% [markdown]
# ## 4. Publication Figures

# %%
# TODO: Generate bar chart, line plot, and qualitative comparison grid

# %% [markdown]
# ## 5. Edge Pipeline Latency

# %%
# TODO: Benchmark ONNX inference latency on CPU

# %% [markdown]
# ## 6. Summary & Conclusions
#
# _(Fill in after running experiments)_
#
# ### Key Findings
# 1. ...
# 2. ...
# 3. ...
#
# ### Recommendations
# - ...
