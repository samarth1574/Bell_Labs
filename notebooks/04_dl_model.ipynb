# %% [markdown]
# # 04 — Deep Learning Model with Soft-NMS
#
# **Project:** High-Density Object Segmentation with Soft-NMS
#
# ---
#
# ## Objectives
# 1. Load a pretrained detector (Faster R-CNN / FCOS) from torchvision
# 2. Implement Hard NMS vs. Soft-NMS (Gaussian & Linear) comparison
# 3. Run inference on synthetic and SKU-110K images
# 4. Sweep Soft-NMS hyperparameters (sigma, score threshold)
# 5. Quantify mAP, count MAE, and FPS improvements
# 6. Export the best model to ONNX format

# %%
import sys
sys.path.append('..')

import torch
import torchvision
import numpy as np
import matplotlib.pyplot as plt
from pathlib import Path

from src.models.soft_nms import *  # noqa
from src.models.detector import *  # noqa
from src.evaluation.metrics import *  # noqa
from src.utils.visualization import setup_style, draw_boxes, COLORS

setup_style()
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f'Using device: {device}')

# %% [markdown]
# ## 1. Load Pretrained Detector

# %%
# TODO: Load Faster R-CNN with ResNet50 / MobileNetV3 backbone

# %% [markdown]
# ## 2. Hard NMS vs. Soft-NMS Comparison

# %%
# TODO: Side-by-side comparison of Hard NMS vs Soft-NMS (Gaussian) vs Soft-NMS (Linear)

# %% [markdown]
# ## 3. Soft-NMS Hyperparameter Sweep

# %%
# TODO: Sweep sigma values (0.1, 0.3, 0.5, 0.7, 1.0) and score thresholds

# %% [markdown]
# ## 4. Full Evaluation

# %%
# TODO: Compute mAP@0.5, mAP@0.5:0.95, count MAE, FPS

# %% [markdown]
# ## 5. ONNX Export

# %%
# TODO: Export best model configuration to ONNX format
